# %%
import pandas as pd
import numpy as np

from eval_ithor.objects import total
df = pd.read_csv('./res/v7_val_0_0/out.csv')
# Out:
# No implementation for OWOD

# %%
df
# Out:
#      Unnamed: 0       score     query_name        scene_name  num_waypoints
# 0             0           1           Book  FloorPlan_Val1_1              0
# 1             1    0.179121           Book  FloorPlan_Val1_1              6
# 2             2           1           Book  FloorPlan_Val1_1              0
# 3             3    0.842382           Book  FloorPlan_Val1_1              1
# 4             4    0.378545         Laptop  FloorPlan_Val1_1              4
# 5             5           1      CellPhone  FloorPlan_Val1_1              0
# 6             6    0.814283     AlarmClock  FloorPlan_Val1_1              2
# 7             7    0.184223         Pillow  FloorPlan_Val1_1              9
# 8             8    0.140483         Pillow  FloorPlan_Val1_1             14
# 9             9    0.223377         Pillow  FloorPlan_Val1_1             10
# 10           10  0.00591966           Bowl  FloorPlan_Val1_1              1
# 11           11           0  RemoteControl  FloorPlan_Val1_1             21
# 12           12    0.110525          Apple  FloorPlan_Val1_1              9
# 13           13           1    SprayBottle  FloorPlan_Val1_1              0
# 14           14    0.619779           Book  FloorPlan_Val1_2              4
# 15           15    0.167345           Book  FloorPlan_Val1_2              7
# 16           16    0.179738           Book  FloorPlan_Val1_2              6
# 17           17   0.0895133         Laptop  FloorPlan_Val1_2             11
# 18           18    0.191093         Pillow  FloorPlan_Val1_2             10
# 19           19           1    SprayBottle  FloorPlan_Val1_2              0
# 20           20           0  RemoteControl  FloorPlan_Val1_2             20
# 21           21    0.478808          Apple  FloorPlan_Val1_2              1
# 22           22           0     AlarmClock  FloorPlan_Val1_2             23
# 23           23     0.18108             CD  FloorPlan_Val1_2              8
# 24           24    0.102589            Pot  FloorPlan_Val1_2              5
# 25           25   0.0736304           Bowl  FloorPlan_Val1_2             12
# 26           26    0.117649           Book  FloorPlan_Val1_3             13
# 27           27    0.111385           Book  FloorPlan_Val1_3              8
# 28           28           0         Pillow  FloorPlan_Val1_3             20
# 29           29    0.163866            Pot  FloorPlan_Val1_3              7
# 30           30    0.131954           Bowl  FloorPlan_Val1_3              8
# 31           31    0.142018  RemoteControl  FloorPlan_Val1_3              9
# 32           32   0.0858536     AlarmClock  FloorPlan_Val1_3             16
# 33           33   0.0124735    SprayBottle  FloorPlan_Val1_3              8
# 34           34    0.629502         Laptop  FloorPlan_Val1_3              2
# 35           35           1          Apple  FloorPlan_Val1_3              0
# 36           36    0.101556           Book  FloorPlan_Val1_4             14
# 37           37           1           Book  FloorPlan_Val1_4              0
# 38           38    0.134355           Book  FloorPlan_Val1_4              9
# 39           39    0.135478           Book  FloorPlan_Val1_4             10
# 40           40           1           Book  FloorPlan_Val1_4              0
# 41           41    0.413121    SprayBottle  FloorPlan_Val1_4              1
# 42           42   0.0846877         Laptop  FloorPlan_Val1_4             18
# 43           43   0.0752021         Pillow  FloorPlan_Val1_4             12
# 44           44    0.281688           Bowl  FloorPlan_Val1_4              2
# 45           45     0.16528  RemoteControl  FloorPlan_Val1_4             11
# 46           46    0.292305          Apple  FloorPlan_Val1_4              2
# 47           47 0.000822169     AlarmClock  FloorPlan_Val1_4              5
# 48           48    0.110713           Book  FloorPlan_Val1_5              7
# 49           49   0.0511466      CellPhone  FloorPlan_Val1_5              6
# 50           50   0.0342121            Pot  FloorPlan_Val1_5              6
# 51           51           0           Bowl  FloorPlan_Val1_5             13
# 52           52           1         Laptop  FloorPlan_Val1_5              0
# 53           53   0.0400862          Apple  FloorPlan_Val1_5              6
# 54           54           1     AlarmClock  FloorPlan_Val1_5              0
# 55           55 0.000405816    SprayBottle  FloorPlan_Val1_5              8
# 56           56           0  RemoteControl  FloorPlan_Val1_5             24
# 57           57     0.13897         Pillow  FloorPlan_Val1_5              3
# 58           58           1           Book  FloorPlan_Val2_1              0
# 59           59           1           Book  FloorPlan_Val2_1              0
# 60           60           1           Book  FloorPlan_Val2_1              0
# 61           61    0.159436          Apple  FloorPlan_Val2_1             11
# 62           62     0.41674           Bowl  FloorPlan_Val2_1              4
# 63           63    0.515176     AlarmClock  FloorPlan_Val2_1              4
# 64           64           0  RemoteControl  FloorPlan_Val2_1             20
# 65           65    0.107693    SprayBottle  FloorPlan_Val2_1              7
# 66           66    0.616989         Pillow  FloorPlan_Val2_1              4
# 67           67           0            Pot  FloorPlan_Val2_1             19
# 68           68    0.194414         Laptop  FloorPlan_Val2_1              5
# 69           69    0.315078      CellPhone  FloorPlan_Val2_1              5
# 70           70           1           Book  FloorPlan_Val2_2              0
# 71           71           1           Book  FloorPlan_Val2_2              0
# 72           72    0.113623         Laptop  FloorPlan_Val2_2              5
# 73           73    0.468752      TeddyBear  FloorPlan_Val2_2              1
# 74           74   0.0688212     AlarmClock  FloorPlan_Val2_2             12
# 75           75   0.0613116         Pillow  FloorPlan_Val2_2              9
# 76           76           1            Pot  FloorPlan_Val2_2              0
# 77           77    0.119451      CellPhone  FloorPlan_Val2_2             15
# 78           78           0  RemoteControl  FloorPlan_Val2_2             18
# 79           79     0.53142            Pot  FloorPlan_Val2_2              3
# 80           80   0.0116897          Apple  FloorPlan_Val2_2             12
# 81           81   0.0855453    SprayBottle  FloorPlan_Val2_2             18
# 82           82    0.469792           Bowl  FloorPlan_Val2_2              1
# 83           83    0.018233           Book  FloorPlan_Val2_3             15
# 84           84   0.0213631           Book  FloorPlan_Val2_3             10
# 85           85   0.0241801           Book  FloorPlan_Val2_3              8
# 86           86    0.146941           Book  FloorPlan_Val2_3              2
# 87           87    0.331439     AlarmClock  FloorPlan_Val2_3              6
# 88           88    0.409186         Laptop  FloorPlan_Val2_3              6
# 89           89     0.35563      CellPhone  FloorPlan_Val2_3              6
# 90           90           0           Bowl  FloorPlan_Val2_3             16
# 91           91    0.193524         Pillow  FloorPlan_Val2_3             11
# 92           92     0.13215         Pillow  FloorPlan_Val2_3              4
# 93           93           0  RemoteControl  FloorPlan_Val2_3             19
# 94           94           0    SprayBottle  FloorPlan_Val2_3             22
# 95           95           0          Apple  FloorPlan_Val2_3             22
# 96           96    0.428766           Book  FloorPlan_Val2_4             11
# 97           97     1.47478           Book  FloorPlan_Val2_4              1
# 98           98     1.47206           Book  FloorPlan_Val2_4              1
# 99           99    0.231067     AlarmClock  FloorPlan_Val2_4              5
# 100         100           0      CellPhone  FloorPlan_Val2_4             36
# 101         101    0.250872            Pot  FloorPlan_Val2_4              2
# 102         102    0.220084         Pillow  FloorPlan_Val2_4              2
# 103         103    0.150936         Pillow  FloorPlan_Val2_4              4
# 104         104    0.361943  RemoteControl  FloorPlan_Val2_4              2
# 105         105     1.77675      TeddyBear  FloorPlan_Val2_4              2
# 106         106    0.185255         Laptop  FloorPlan_Val2_4              8
# 107         107    0.248822          Apple  FloorPlan_Val2_4              9
# 108         108     2.92929           Bowl  FloorPlan_Val2_4              1
# 109         109           1            Pot  FloorPlan_Val2_4              0
# 110         110           0             CD  FloorPlan_Val2_4             22
# 111         111           0    SprayBottle  FloorPlan_Val2_4             19
# 112         112    0.248878           Book  FloorPlan_Val2_5              3
# 113         113     0.27624           Book  FloorPlan_Val2_5             11
# 114         114    0.322713           Book  FloorPlan_Val2_5              1
# 115         115    0.728131           Book  FloorPlan_Val2_5              5
# 116         116     0.19984           Book  FloorPlan_Val2_5              8
# 117         117    0.476187         Pillow  FloorPlan_Val2_5              2
# 118         118    0.261364     AlarmClock  FloorPlan_Val2_5              3
# 119         119           1          Apple  FloorPlan_Val2_5              0
# 120         120           1            Pot  FloorPlan_Val2_5              0
# 121         121    0.129032      CellPhone  FloorPlan_Val2_5              5
# 122         122           1         Laptop  FloorPlan_Val2_5              0
# 123         123           0    SprayBottle  FloorPlan_Val2_5             22
# 124         124    0.553966  RemoteControl  FloorPlan_Val2_5              5
# 125         125           1           Bowl  FloorPlan_Val2_5              0
# 126         126   0.0110096           Book  FloorPlan_Val3_1              5
# 127         127           1           Book  FloorPlan_Val3_1              0
# 128         128    0.435663         Laptop  FloorPlan_Val3_1              2
# 129         129    0.646229     AlarmClock  FloorPlan_Val3_1              3
# 130         130    0.330586         Pillow  FloorPlan_Val3_1              6
# 131         131    0.211985    SprayBottle  FloorPlan_Val3_1              2
# 132         132   0.0609232           Bowl  FloorPlan_Val3_1              7
# 133         133    0.455984      CellPhone  FloorPlan_Val3_1              1
# 134         134    0.375879      CellPhone  FloorPlan_Val3_1              2
# 135         135           0  RemoteControl  FloorPlan_Val3_1             22
# 136         136   0.0448227          Apple  FloorPlan_Val3_1              3
# 137         137   0.0390741           Book  FloorPlan_Val3_2              5
# 138         138     0.30134           Book  FloorPlan_Val3_2              7
# 139         139    0.455282           Book  FloorPlan_Val3_2              5
# 140         140    0.318157           Book  FloorPlan_Val3_2              5
# 141         141    0.247405         Pillow  FloorPlan_Val3_2              9
# 142         142    0.259086         Laptop  FloorPlan_Val3_2              8
# 143         143    0.207337    SprayBottle  FloorPlan_Val3_2              9
# 144         144  0.00611467  RemoteControl  FloorPlan_Val3_2              1
# 145         145    0.193697          Apple  FloorPlan_Val3_2              8
# 146         146    0.252974     AlarmClock  FloorPlan_Val3_2              9
# 147         147  0.00288348      CellPhone  FloorPlan_Val3_2              2
# 148         148  0.00518809           Bowl  FloorPlan_Val3_2              1
# 149         149    0.186936           Book  FloorPlan_Val3_3             14
# 150         150    0.610788           Book  FloorPlan_Val3_3              4
# 151         151    0.307997           Book  FloorPlan_Val3_3              8
# 152         152           1           Bowl  FloorPlan_Val3_3              0
# 153         153    0.515288         Pillow  FloorPlan_Val3_3              5
# 154         154    0.105029  RemoteControl  FloorPlan_Val3_3             21
# 155         155           1            Pot  FloorPlan_Val3_3              0
# 156         156    0.318642     AlarmClock  FloorPlan_Val3_3              8
# 157         157           1      CellPhone  FloorPlan_Val3_3              0
# 158         158    0.156037         Laptop  FloorPlan_Val3_3             12
# 159         159    0.165755          Apple  FloorPlan_Val3_3             11
# 160         160    0.240074    SprayBottle  FloorPlan_Val3_3              9
# 161         161    0.395088           Book  FloorPlan_Val3_4              7
# 162         162   0.0999025           Book  FloorPlan_Val3_4             14
# 163         163           1         Pillow  FloorPlan_Val3_4              0
# 164         164    0.371028            Pot  FloorPlan_Val3_4              4
# 165         165   0.0747835         Laptop  FloorPlan_Val3_4              5
# 166         166  0.00527089           Bowl  FloorPlan_Val3_4              1
# 167         167    0.346411  RemoteControl  FloorPlan_Val3_4              4
# 168         168           1          Apple  FloorPlan_Val3_4              0
# 169         169           1     AlarmClock  FloorPlan_Val3_4              0
# 170         170           0    SprayBottle  FloorPlan_Val3_4             18
# 171         171           1           Book  FloorPlan_Val3_5              0
# 172         172  0.00620001           Book  FloorPlan_Val3_5              2
# 173         173           1           Book  FloorPlan_Val3_5              0
# 174         174    0.152432           Bowl  FloorPlan_Val3_5             11
# 175         175     0.19132            Pot  FloorPlan_Val3_5              6
# 176         176    0.164744         Laptop  FloorPlan_Val3_5              8
# 177         177    0.211405          Apple  FloorPlan_Val3_5              8
# 178         178    0.569387         Pillow  FloorPlan_Val3_5              1
# 179         179     0.17689      CellPhone  FloorPlan_Val3_5              1
# 180         180    0.236696     AlarmClock  FloorPlan_Val3_5             11
# 181         181     0.20929  RemoteControl  FloorPlan_Val3_5              1
# 182         182    0.283994    SprayBottle  FloorPlan_Val3_5             10

# %%
obj_score = []

for obj in total:
    temp = df.loc[df['query_name'] == obj, ['score']]
    temp2 = df.loc[df['query_name'] == obj, ['num_waypoints']]
    temp = np.clip(temp,0,1)
    mean_score = temp.mean().item()
    mean_score = np.nan_to_num(mean_score,nan=100)
    mean_points = temp2.mean().item()
    if mean_score != 100:
        success_rate = (temp>0).sum().item()/(len(temp))
        obj_score.append(dict(object=obj,SPL=mean_score,success_rate = success_rate,num_waypoints =  mean_points))
obj_score = pd.DataFrame(obj_score)

# %%
obj_score
# Out:
#            object       SPL  success_rate  num_waypoints
# 0   RemoteControl  0.126004      0.533333           13.2
# 1          Laptop  0.345003             1        6.26667
# 2            Book  0.474925             1        5.15217
# 3           Apple   0.33049      0.933333            6.8
# 4              CD 0.0905402           0.5             15
# 5             Pot  0.470442      0.916667        4.33333
# 6            Bowl  0.306903      0.866667            5.2
# 7      AlarmClock  0.384224      0.933333        7.13333
# 8       TeddyBear  0.734376             1            1.5
# 9       CellPhone  0.331831      0.916667        6.58333
# 10    SprayBottle  0.237509      0.733333           10.2
# 11         Pillow  0.287747      0.947368        7.10526

# %%
spl = df['score'].to_numpy()
num_points = df['num_waypoints'].to_numpy()
spl = np.clip(spl,a_min=0,a_max=1)
success = (spl>0)
mean_spl = spl.mean()
mean_points = num_points.mean()
mean_success = success.mean()
temp = pd.DataFrame([dict(object='Average',SPL=mean_spl,success_rate=mean_success,num_waypoints = mean_points)])
total_obj_score = pd.concat((obj_score,temp))

# %%
total_obj_score
# Out:
#            object       SPL  success_rate  num_waypoints
# 0   RemoteControl  0.126004      0.533333           13.2
# 1          Laptop  0.345003             1        6.26667
# 2            Book  0.474925             1        5.15217
# 3           Apple   0.33049      0.933333            6.8
# 4              CD 0.0905402           0.5             15
# 5             Pot  0.470442      0.916667        4.33333
# 6            Bowl  0.306903      0.866667            5.2
# 7      AlarmClock  0.384224      0.933333        7.13333
# 8       TeddyBear  0.734376             1            1.5
# 9       CellPhone  0.331831      0.916667        6.58333
# 10    SprayBottle  0.237509      0.733333           10.2
# 11         Pillow  0.287747      0.947368        7.10526
# 0         Average  0.352693      0.896175        6.92896

# %%
from co_occurance.fliker import fliker_knowledge

# %%
landmark_names = ['Bed', 'DiningTable', 'StoveBurner', 'Toilet', 'Sink', 'Desk','Drawer','Shelf',
                        'CounterTop','Television','Sofa','SideTable','CoffeeTable',
                        'ShelvingUnit','ArmChair','TVStand']

object_names = ['RemoteControl','Laptop','Book','Apple','CD']
f = fliker_knowledge(landmark_names,object_names)
# Out:
# bed on
# 1480940
# bed remote%20control
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jeongeun/test_env/ITHOR_Navi/res.ipynb Cell 8' in <cell line: 6>()
#       <a href='vscode-notebook-cell://ssh-remote%2B163.152.26.197/home/jeongeun/test_env/ITHOR_Navi/res.ipynb#ch0000007vscode-remote?line=0'>1</a> landmark_names = ['Bed', 'DiningTable', 'StoveBurner', 'Toilet', 'Sink', 'Desk','Drawer','Shelf',
#       <a href='vscode-notebook-cell://ssh-remote%2B163.152.26.197/home/jeongeun/test_env/ITHOR_Navi/res.ipynb#ch0000007vscode-remote?line=1'>2</a>                         'CounterTop','Television','Sofa','SideTable','CoffeeTable',
#       <a href='vscode-notebook-cell://ssh-remote%2B163.152.26.197/home/jeongeun/test_env/ITHOR_Navi/res.ipynb#ch0000007vscode-remote?line=2'>3</a>                         'ShelvingUnit','ArmChair','TVStand']
#       <a href='vscode-notebook-cell://ssh-remote%2B163.152.26.197/home/jeongeun/test_env/ITHOR_Navi/res.ipynb#ch0000007vscode-remote?line=4'>5</a> object_names = ['RemoteControl','Laptop','Book','Apple','CD']
# ----> <a href='vscode-notebook-cell://ssh-remote%2B163.152.26.197/home/jeongeun/test_env/ITHOR_Navi/res.ipynb#ch0000007vscode-remote?line=5'>6</a> f = fliker_knowledge(landmark_names,object_names)
#
# File ~/test_env/ITHOR_Navi/co_occurance/fliker.py:35, in fliker_knowledge.__init__(self, landmark_names, object_names)
#      33 else:
#      34     new_query_object_name = query_object_name
# ---> 35 num = self.crawl(landmark_name.lower(),new_query_object_name,relation)
#      36 self.co_matrix[i,j] += num/base_num
#      37 print(num/base_num)
#
# File ~/test_env/ITHOR_Navi/co_occurance/fliker.py:64, in fliker_knowledge.crawl(self, landmark_name, query_object, relation)
#      62 url_name = self.web_format(landmark_name,query_object,relation)
#      63 fp = urllib.request.urlopen(url_name)
# ---> 64 mybytes = fp.read()
#      66 mystr = mybytes.decode("utf8")
#      67 fp.close()
#
# File ~/.pyenv/versions/3.8.8/lib/python3.8/http/client.py:471, in HTTPResponse.read(self, amt)
#     469 else:
#     470     try:
# --> 471         s = self._safe_read(self.length)
#     472     except IncompleteRead:
#     473         self._close_conn()
#
# File ~/.pyenv/versions/3.8.8/lib/python3.8/http/client.py:612, in HTTPResponse._safe_read(self, amt)
#     605 def _safe_read(self, amt):
#     606     """Read the number of bytes requested.
#     607
#     608     This function should be used when <amt> bytes "should" be present for
#     609     reading. If the bytes are truly not available (due to EOF), then the
#     610     IncompleteRead exception can be used to detect the problem.
#     611     """
# --> 612     data = self.fp.read(amt)
#     613     if len(data) < amt:
#     614         raise IncompleteRead(data, amt-len(data))
#
# File ~/.pyenv/versions/3.8.8/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.8.8/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.8.8/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pandas as pd
m = f.co_matrix
df = pd.DataFrame(m.T)
df.columns = landmark_names
df.index = object_names

# %%
df

# %%
m
